# %%
import shap
import transformers
import torch
import datasets
import yaml
import numpy as np
import scipy as sp
import pandas as pd
from tqdm import tqdm

# %%
# !pip install shap
# Out:
# WARNING: Keyring is skipped due to an exception: Failed to create the collection: Prompt dismissed..
# Collecting shap
#   Using cached shap-0.38.1-cp37-cp37m-linux_x86_64.whl
# Requirement already satisfied: numba in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from shap) (0.48.0)
# Requirement already satisfied: scipy in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from shap) (1.4.1)
# Requirement already satisfied: tqdm>4.25.0 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from shap) (4.42.1)
# Requirement already satisfied: slicer==0.0.7 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from shap) (0.0.7)
# Requirement already satisfied: cloudpickle in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from shap) (1.3.0)
# Requirement already satisfied: scikit-learn in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from shap) (0.22.1)
# Requirement already satisfied: numpy in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from shap) (1.20.1)
# Requirement already satisfied: pandas in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from shap) (1.0.1)
# Requirement already satisfied: llvmlite<0.32.0,>=0.31.0dev0 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from numba->shap) (0.31.0)
# Requirement already satisfied: setuptools in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from numba->shap) (45.2.0.post20200210)
# Requirement already satisfied: python-dateutil>=2.6.1 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from pandas->shap) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from pandas->shap) (2019.3)
# Requirement already satisfied: six>=1.5 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from python-dateutil>=2.6.1->pandas->shap) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from scikit-learn->shap) (0.14.1)
# Installing collected packages: shap
# Successfully installed shap-0.38.1
# WARNING: You are using pip version 20.3.3; however, version 21.0.1 is available.
# You should consider upgrading via the '/home/ubuntu/anaconda3/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# # 3. Classification Perspective

# %% [markdown]
# ## b) Explainable classification models

# %%
config = yaml.safe_load(open("config.yaml"))

# %%
dataset_names = config['datasets']
path_models = './tmp/models/'
path_combined_test_set = './tmp/datasets/combined_test'

# %% [markdown]
# ### Load tokenizer and combiend test data set

# %%
# tokenizer
tokenizer = transformers.DistilBertTokenizerFast.from_pretrained("bert-base-uncased")

# load combined test data set
combined_test_dataset = datasets.load_from_disk(path_combined_test_set)
selected_test_data = combined_test_dataset[:20]
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=28.0, style=ProgressStyle(description_w…

# %% [markdown]
# ### Define prediction function

# %%
def predict(x):
    val = []
    for record in x:
        inputs =  tokenizer(record, return_tensors="pt")
        labels = torch.tensor([1]).unsqueeze(0)
        outputs = model(**inputs, labels=labels)
        m = torch.nn.Softmax(dim=1).cuda()
        # softmax the logits
        softmaxed = m(outputs.logits).detach().cpu().numpy()
        # get the probaility for the positive class (hate)
        val.append(softmaxed[0][1])
    return np.array(val)

# %% [markdown]
# ### Prediction for combined test data set by each classifier

# %%
df = pd.DataFrame(combined_test_dataset['label'],columns =['Labels'])
for i,dataset_name in enumerate(tqdm(dataset_names)):
    predictions = []
    # load model
    path_to_model = '{}{}_{}_model'.format(path_models,i,dataset_name)
    model = transformers.BertForSequenceClassification.from_pretrained(path_to_model)
    # predict test set
    for record in combined_test_dataset:
        inputs =  tokenizer(record['text'], return_tensors="pt")
        labels = torch.tensor([1]).unsqueeze(0)
        outputs = model(**inputs, labels=labels)
        m = torch.nn.Softmax(dim=1).cuda()
        # softmax the logits
        softmaxed = m(outputs.logits).detach().cpu().numpy()
        # get the probaility for the positive class (hate)
        if softmaxed[0][1] >= 0.5:
            predictions.append(1)
        else:
            predictions.append(0)
            
    df[dataset_name] = predictions
# Out:
# 100%|██████████| 5/5 [44:10<00:00, 530.12s/it]

# %% [markdown]
# ### Calculate error rate for each document in combined test set

# %%
def calculateError(x):
    error = 0
    for dataset in dataset_names:
        if x['Labels'] != x[dataset]:
            error += 1
    return error
    
df['Error'] = df.apply(lambda x: calculateError(x), axis=1)
#df.head()

# %% [markdown]
# ### Filter doucments that have n errors

# %%
number_of_error = 2
selected_test_data = []
for label in range(2):
    errorLabel = 0 if label == 1 else 1
    for dataset in dataset_names:
        for i in range(5):
            try:
                index = df[(df['Labels'] == label) & (df['Error'] == number_of_error) & (df[dataset] == errorLabel)].index[i]
                #print(type(index), index)
                selected_test_data.append(combined_test_dataset[int(index)]['text'])
            except:
                break

print(len(selected_test_data))
# Out:
# 50

# %% [markdown]
# ### Get explanations for filtered documents

# %%
shap_values_of_models = []
for i,dataset_name in enumerate(dataset_names):
    path_to_model = '{}{}_{}_model'.format(path_models,i,dataset_name)
    model = transformers.BertForSequenceClassification.from_pretrained(path_to_model)
    
    explainer = shap.Explainer(predict, masker=tokenizer)
    
    shap_values = explainer(selected_test_data)
    
    shap_values_of_models.append(shap_values)
# Out:
# explainers.Partition is still in an alpha state, so use with caution...
# Partition explainer: 51it [03:02,  3.57s/it]
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# explainers.Partition is still in an alpha state, so use with caution...
# Partition explainer: 51it [01:49,  2.15s/it]
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# explainers.Partition is still in an alpha state, so use with caution...
# Partition explainer: 51it [01:49,  2.15s/it]
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# explainers.Partition is still in an alpha state, so use with caution...
# Partition explainer: 51it [01:48,  2.13s/it]
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# explainers.Partition is still in an alpha state, so use with caution...
# Partition explainer: 51it [01:49,  2.14s/it]
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.

# %% [markdown]
# ### Print explanations of different classifiers for selected document

# %%
selected_item_to_explain = 35


#40#13#46

global_min = 1
global_max = 0

for i,dataset_name in enumerate(dataset_names):
    min_val = shap_values_of_models[i].base_values[selected_item_to_explain]
    max_val = shap_values_of_models[i].base_values[selected_item_to_explain]
    for elem in shap_values_of_models[i].values[selected_item_to_explain]:
        if  elem < 0:
            min_val = min_val + elem
        else:
            max_val = max_val + elem
    global_min = min(min_val,global_min)
    global_max = max(max_val,global_max)

for i,dataset_name in enumerate(dataset_names):
    #print(dataset_name)
    shap.plots.text(shap_values_of_models[i][selected_item_to_explain],xmin=global_min-0.05,xmax=global_max+0.05)
# Out:
# <svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="12.709646%" y1="33" x2="12.709646%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="12.709646%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.027800</text><text x="12.709646%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="26.995360%" y1="33" x2="26.995360%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="26.995360%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.200278</text><line x1="41.281075%" y1="33" x2="41.281075%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="41.281075%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.372755</text><line x1="55.566789%" y1="33" x2="55.566789%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="55.566789%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.545232</text><line x1="69.852503%" y1="33" x2="69.852503%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="69.852503%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.717709</text><line x1="84.138218%" y1="33" x2="84.138218%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="84.138218%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.890187</text><line x1="88.478894%" y1="33" x2="88.478894%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="88.478894%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.942594</text><text x="88.478894%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0.942594</text><text x="88.478894%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f(x)</text><rect x="12.107037252558605%" width="76.37185675954996%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="65.99289046415998%" x2="88.47889401210855%" y1="60" y2="60" id="_fb_deepazyffstxukruicxp_ind_4" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="77.23589223813427%" y="71" font-size="12px" id="_fs_deepazyffstxukruicxp_ind_4" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.271</text><svg x="65.99289046415998%" y="40" height="20" width="22.48600354794857%">  <svg x="0" y="0" width="100%" height="100%">    <text x="50%" y="9" font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle" text-anchor="middle">should be</text>  </svg></svg><line x1="48.28588115005544%" x2="65.99289046415998%" y1="60" y2="60" id="_fb_deepazyffstxukruicxp_ind_3" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="57.139385807107715%" y="71" font-size="12px" id="_fs_deepazyffstxukruicxp_ind_3" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.214</text><svg x="48.28588115005544%" y="40" height="20" width="17.707009314104546%">  <svg x="0" y="0" width="100%" height="100%">    <text x="50%" y="9" font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle" text-anchor="middle">all girls</text>  </svg></svg><line x1="33.1967335269335%" x2="48.28588115005544%" y1="60" y2="60" id="_fb_deepazyffstxukruicxp_ind_6" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="40.741307338494465%" y="71" font-size="12px" id="_fs_deepazyffstxukruicxp_ind_6" fill="rgb(255.0, 0 ...
# <svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="26.347498%" y1="33" x2="26.347498%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="26.347498%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.192456</text><text x="26.347498%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="12.061784%" y1="33" x2="12.061784%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="12.061784%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.019979</text><line x1="40.633212%" y1="33" x2="40.633212%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="40.633212%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.364933</text><line x1="54.918926%" y1="33" x2="54.918926%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="54.918926%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.537410</text><line x1="69.204641%" y1="33" x2="69.204641%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="69.204641%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.709888</text><line x1="83.490355%" y1="33" x2="83.490355%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="83.490355%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.882365</text><line x1="92.747411%" y1="33" x2="92.747411%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="92.747411%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.994129</text><text x="92.747411%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0
">  <svg x="0" y="0" width="100%" height="100%">    <text x="50%" y="9" font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle" text-anchor="middle">hoes all year round</text>  </svg></svg><line x1="33.53729017089865%" x2="59.22673717650203%" y1="60" y2="60" id="_fb_wppirqzytenrqnszdsgk_ind_2" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="46.38201367370034%" y="71" font-size="12px" id="_fs_wppirqzytenrqnszdsgk_ind_2" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.31</text><svg x="33.53729017089865%" y="40" height="20" width="25.689447005603377%">  <svg x="0" y="0" width="100%" height="100%">    <text x="50%" y="9" font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle" text-anchor="middle">nuns for Halloween cause y'all been</text>  </svg></svg><line x1="25.98939405967552%" x2="33.53729017089865%" y1="60" y2="60" id="_fb_wppirqzytenrqnszdsgk_ind_1" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="29.763342115287085%" y="71" font-size="12px" id="_fs_wppirqzyte ...
# <svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="14.930371%" y1="33" x2="14.930371%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="14.930371%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.054612</text><text x="14.930371%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="29.216085%" y1="33" x2="29.216085%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="29.216085%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.227089</text><line x1="43.501800%" y1="33" x2="43.501800%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="43.501800%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.399567</text><line x1="57.787514%" y1="33" x2="57.787514%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="57.787514%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.572044</text><line x1="72.073228%" y1="33" x2="72.073228%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="72.073228%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.744521</text><line x1="86.358943%" y1="33" x2="86.358943%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="86.358943%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.916998</text><line x1="10.860671%" y1="33" x2="10.860671%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="10.860671%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.005477</text><text x="10.860671%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0.005477</text><text x="10.860671%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f(x)</text><rect x="8.653876713989188%" width="2.2067945387429013%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="9.864122657039509%" x2="10.86067125273209%" y1="60" y2="60" id="_fb_nlbwnwcxpkwabpyfkolc_ind_3" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="10.3623969548858%" y="71" font-size="12px" id="_fs_nlbwnwcxpkwabpyfkolc_ind_3" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.012</text><svg x="9.864122657039509%" y="40" height="20" width="0.9965485956925804%">  <svg x="0" y="0" width="100%" height="100%">    <text x="50%" y="9" font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle" text-anchor="middle">y'</text>  </svg></svg><line x1="9.041451865117132%" x2="9.864122657039509%" y1="60" y2="60" id="_fb_nlbwnwcxpkwabpyfkolc_ind_4" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="9.45278726107832%" y="71" font-size="12px" id="_fs_nlbwnwcxpkwabpyfkolc_ind_4" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.01</text><svg x="9.041451865117132%" y="40" height="20" width="0.822670791922377%">  <svg x="0" y="0" width="100%" height="100%">    <text x="50%" y="9" font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle" text-anchor="middle">all girls should be</text>  </svg></svg><line x1="8.867478703907597%" x2="9.041451865117132%" y1="60" y2="60" id="_fb_nlbwnwcxpkwabpyfkolc_ind_10" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="8.954465284512365%" y="71" font-size="12px" id="_fs_nlbwnwcxpkwabpyfkolc_ind_10" fill="rgb(255.0,  ...

# %%
selected_test_data
# Out:
# ['[UNK] [UNK] [UNK] [UNK] And there is nothing wrong with stoping the Muslim genocide of non Muslims.',
#  '[UNK] [UNK] [UNK] And I doubt that you would find those Serbs in a church. But all the ISIS go to Mosque 5 per day.',
#  ' [UNK]: .[UNK] Islam is not a religion. This is what an honest ex-Muslim woman victim of Islam says: [UNK]',
#  '[UNK] [UNK] [UNK] They are lying. The terrorist do exactly what the prophet Mohammed did. [UNK]',
#  '[UNK] [UNK] ISIS seems to look for ever more gruesome ways to murder people. Jordanian pilot burned alive.',
#  ' [UNK]: TO RECAP: [UNK] started [UNK]. There are over 50 vigils scheduled for [UNK] tonight because of A BLACK FEM...',
#  'Im with [UNK] booooo [UNK]',
#  "[UNK] Not that you'll stop whining for ten seconds to read, but [UNK] Feminists do not owe you their civility.",
#  " [UNK] Naah I'm not sexist but can someone get me this T-Shirt please? [UNK]",
#  "[UNK] i'm an engineer w/15 yrs exp, and i get mansplained career advice by dudes with 1/2 the xp and bad life decisions.",
#  '[UNK] One of the reasons why the Daesh will be destroyed is their display of joy in murder and cruelty.',
#  'That chicken thing is disgusting [UNK]',
#  '[UNK] All your followers need to read Masha Gessen\'s book, "The Man Without A Face" to understand what a criminal and thug Putin is.',
#  '[UNK] [UNK] [UNK] [UNK] And there is nothing wrong with stoping the Muslim genocide of non Muslims.',
#  'Kat and Andre are horrible people. [UNK]',
#  'That chicken thing is disgusting [UNK]',
#  '[UNK] All your followers need to read Masha Gessen\'s book, "The Man Without A Face" to understand what a criminal and thug Putin is.',
#  'Kat and Andre are horrible people. [UNK]',
#  '[UNK] [UNK] This is a total fraud that only idiots would believe.  No such license ever existed.',
#  'Sending someone to jail for stealing tylenol is pretty ridiculous.',
#  '[UNK] One of the reasons why the Daesh will be destroyed is their display of joy in murder and cruelty.',
#  '[UNK] Do you suggest they drive out ISIS by shelling them with cotton candy.',
#  "Apparently ISIS has decided to start attacking the Saudi border from Anbar Iraq.  This will no doubt turn up Saudi's war against them.",
#  ' [UNK]: The message is clear: This target *WILL* be left COMPLETELY ISOLATED as we torture, terrorize and abuse them with impunity... ...',
#  '[UNK] dems offended by [UNK] but not organ harvesting the lungs of political prisoners by the chinese communist system. [UNK]',
#  '[UNK] [UNK] Poor kid. All he wanted was to grow up and behead Kuffir. We feel so bad for him.At 14 ISIS would have sent him to kill',
#  'Top-notch commentary A+ would ridicule again. [UNK] [UNK] hahahahahaha what a fuckin pussy',
#  ' [UNK]: [UNK] 3 Hours away, probably fucking some dude instead of making me a sandwich.',
#  "[UNK] y'all niccas bout to blow fool!! Lol can't wait for the world to see this Detroit shit nicca!",
#  "' Broke Tf outta this niggah at 24   He stopped playen defense and all",
#  'Also - Kat is a completely rank cow but by God Annie is annoying... [UNK]',
#  ' [UNK] I am not sexist. But womens darts .....',
#  '[UNK] You can preach coexistence all you want.  To Islamist you are just a useful idiot.',
#  '[UNK] [UNK] "I hate it when women control the conversation on their own problems, but that doesn\'t make me sexist."',
#  '[UNK] [UNK] Poor kid. All he wanted was to grow up and behead Kuffir. We feel so bad for him.At 14 ISIS would have sent him to kill',
#  " [UNK] Some of y'all girls should be nuns for Halloween cause y'all been hoes all year round.",
#  "I have some news for you. [UNK] I'm not sexist but sexist jokes are the funniest jokes out there... in my opinion",
#  ' [UNK]: [UNK] [UNK] [UNK] "hey I have a gender studies degree, clearly YOU ALL are the brainwashed ones"',
#  " [UNK]: In the film, Jennifer Lopez plays a rapist that does not know what the Iliad is. And she's the *protagonist*! [UNK]",
#  '[UNK] [UNK] I actually wish they would just start using "egalitarian" so we can just let feminist mean the misandrist hypocrites.',
#  ' [UNK] Call me sexist but the true definition of a [UNK] is a good house wife   mother who also has good health,looks and physique',
#  'HAHA [UNK] Im not sexist....but I honestly think only men should be reporting on Football on Sportscenter...just saying haha',
#  ' [UNK]: Im not sexist but a girl should know how to cook! if i know how too then she should too just saying',
#  'Gold mine! [UNK] And no im not sexist lighten up and learn to take a joke',
#  '[UNK] gaaaaah I just want to slap her back to WA [UNK]',
#  " [UNK] Some of y'all girls should be nuns for Halloween cause y'all been hoes all year round.",
#  'Also - Kat is a completely rank cow but by God Annie is annoying... [UNK]',
#  ' [UNK] I am not sexist. But womens darts .....',
#  '[UNK] You can preach coexistence all you want.  To Islamist you are just a useful idiot.',
#  '[UNK] [UNK] "I hate it when women control the conversation on their own problems, but that doesn\'t make me sexist."']
